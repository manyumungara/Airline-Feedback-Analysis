# %%
from google.colab import files
files = files.upload()
# Out:
#      <input type="file" id="files-4ec0b13c-ffea-435a-b625-f7da2479b862" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4ec0b13c-ffea-435a-b625-f7da2479b862">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
import pandas as pd
df = pd.read_csv(io.BytesIO(files['Airline_Review.csv']))

# %%
def check_verified(row):
    if 'Verified' in row['Review_content']:
      print('Yes')
    return row
df = df.apply(check_verified,axis=1)

# %%
df_new
# Out:
#          Passanger_Name          Flying_month                  Route  Rating  \
# 0            Paige Boet                Jun-23  New Orleans to London     1.0
# 1               S Layne                Mar-23        London to Amman     1.0
# 2           E Lanewoski    Heathrow to Bodrum         Business Class     2.0
# 3           Joel Burman                Jun-23        Amman to London     4.0
# 4               R Vines  London City to Ibiza         Business Class     7.0
# ...                 ...                   ...                    ...     ...
# 3575           W Benson                   NaN                    NaN     4.0
# 3576           S Luqman                   NaN                    NaN     4.0
# 3577            D Smith                   NaN                    NaN     4.0
# 3578           W Benson                   NaN                    NaN     6.0
# 3579  Michael Dielissen                   NaN                    NaN     8.0
#
# ...

# %%
df[['Flying_month','Route','Traveller_type','Class']].sample(10)
# Out:
#                      Flying_month               Route  Traveller_type  \
# 2407                       Dec-15  Gatwick to Funchal  Couple Leisure
# 2849                          NaN                 NaN  Business Class
# 529                        Jan-20   Gatwick to Cancun    Solo Leisure
# 1636         Mauritius to Gatwick      Business Class      Boeing 777
# 2707                   LHR to ZRH      Business Class            A319
# 1918                       Oct-16          ATH to LHR  Couple Leisure
# 2160                   LHR to DEN     Premium Economy  Boeing 747-400
# 830          Gatwick to Mauritius       Economy Class      Boeing 777
# 921              Nassau to London     Premium Economy      Boeing 777
# 1624  Marrakech to London Gatwick       Economy Class            A320
#
#                 Class
# 2407    Economy Class
# 2849              yes
# 529   Premium Economy
# 1636   Couple Leisure
# 2707     Solo Leisure
# 1918    Economy Class
# 2160     Solo Leisure
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# Economy Class                              676
# Couple Leisure                             641
# Solo Leisure                               553
# yes                                        441
# Business                                   430
# no                                         322
# Family Leisure                             234
# Business Class                             183
# Premium Economy                             85
# First Class                                 11
# London to Malaga                             1
# LHR to ORD                                   1
# Los Angeles to London to Paris to Rome       1
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# Passanger_Name     object
# Flying_month       object
# Route              object
# Rating            float64
# Verified           object
# Review_title       object
# Review_content     object
# Traveller_type     object
# Class              object
# dtype: object

# %%
df[['Passanger_Name','Flying_month']].sample(10)
# Out:
#           Passanger_Name                  Flying_month
# 3426         Harris Lisa                           NaN
# 1703            K Carter             Bangkok to London
# 167            R Gonzaga  Baltimore to London Heathrow
# 1749           J Hicklin            SFO to JNB via LHR
# 3319        Paula Loguda                           NaN
# 1530          R Stratton       London to San Francisco
# 1040              L Wang                        Jul-18
# 348               R Teel    Glasgow to London Heathrow
# 471             M Irving                        Mar-20
# 1706  Christopher Loftus    Chicago to London Heathrow

# %%
df.isnull().sum()
# Out:
# Passanger_Name       0
# Flying_month       765
# Route              764
# Rating               5
# Verified          2310
# Review_title         0
# Review_content       0
# Traveller_type       0
# Class                1
# dtype: int64

# %%
list(df.columns)
# Out:
# ['Passanger_Name',
#  'Flying_month',
#  'Route',
#  'Rating',
#  'Verified',
#  'Review_title',
#  'Review_content',
#  'Traveller_type',
#  'Class']

# %%
df['Traveller_type'].value_counts()
# Out:
# Traveller_type
# A320                   342
# Economy Class          327
# Couple Leisure         308
# Solo Leisure           307
# Business Class         295
#                       ...
# A321Neo                  1
# A319 / Boeing 787-8      1
# Boeing 757               1
# A319/320                 1
# no                       1
# Name: count, Length: 203, dtype: int64

# %%
df[['Passanger_Name','Flying_month']].sample(5)
# Out:
#      Passanger_Name                    Flying_month
# 1244    Clive Drake        London Heathrow to Dubai
# 2658  Desmond Jones                          Aug-15
# 808     Henry Goode                          Mar-19
# 759   Dan Winkowski  London Heathrow to Los Angeles
# 3410       H Sueess                             NaN

# %%
from google.colab import files
files = files.upload()
# Out:
#      <input type="file" id="files-e599d0bf-3168-4069-a6ca-cc1afa58a3e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e599d0bf-3168-4069-a6ca-cc1afa58a3e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
df = pd.read_excel(io.BytesIO(files["Airline_V10_Test.xlsx"]))

# %%
df2 = df[['Passanger_Name',
 'Flying_month',
 'Route',
 'Rating',
 'Verified',
 'Review_title',
 'Review_content',
 'Traveller_type',
 'Class']]

# %%
df.isnull().sum()
# Out:
# Passanger_Name       0
# Flying_month      2630
# Route              141
# Rating               5
# Verified          2310
# Review_title         0
# Review_content       0
# Traveller_type     766
# Class                1
# dtype: int64

# %%
df['Verified'].value_counts()
# Out:
# Verified
# Trip Verified    1067
# Not Verified      203
# Name: count, dtype: int64

# %%
def fill_verified(row):
  if pd.isnull(row['Verified']):
    if str(row['Review_content']).startswith('Verified Review'):
        row['Verified'] = 'Trip Verified'
    elif 'Unverified' in str(row['Review_content']):
            row['Verified'] = 'Not Verified'
  return row
df=df.apply(fill_verified,axis=1)

# %%
df['Verified'].isnull().sum()
# Out:
# 1520

# %%
def stanstead_to_heathrow(row):
  if row['Destination'] == 'Stansted (London)':
    row['Destination'] = 'London - Heathrow'
  return row
df = df.apply(stanstead_to_heathrow,axis = 1)

# %%
df['Destination'].head()
# Out:
# 0                                    London - Heathrow
# 1    Amman - Queen Alia International Airport Jorda...
# 2                               Bodrum - Milas Airport
# 3                                    London - Heathrow
# 4                                                Ibiza
# Name: Destination, dtype: object

# %%
df.to_excel('Airline_V11_Test.xlsx')

# %%
def fill_not_verified(row):
  if pd.isnull(row['Verified']):
    if str(row['Review_content']).startswith('âŽ Unverified'):
        row['Verified'] = 'Not Verified'
  return row
df=df.apply(fill_not_verified,axis=1)

# %%
df.isnull().sum()
# Out:
# Passanger_Name       0
# Flying_month      2630
# Route              141
# Rating               5
# Verified          1540
# Review_title         0
# Review_content       0
# Traveller_type     766
# Class                1
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Passanger_Name       0
# Flying_month      2630
# Route              141
# Rating               5
# Verified          1540
# Review_title         0
# Review_content       0
# Traveller_type     766
# Class                1
# dtype: int64

# %%
df.iloc[1976:1979,4]
# Out:
# 1976    Trip Verified
# 1977    Trip Verified
# 1978              NaN
# Name: Verified, dtype: object

# %%
import numpy as np
df['Verified_Filled'] = df['Review_content'].apply(lambda x: 'Verified Review' if str(x).startswith('Verified Review') else np.nan)

# Optionally, you might want to fill NaN values in 'Verified' where it does not start with 'Verified Review'


# Show the updated DataFrame to confirm changes

# %%
df[['Verified_Filled']].sample(10)

# %%
from google.colab import files
files = files.upload()
# Out:
#      <input type="file" id="files-5b893f5d-9a07-496a-9ebb-0148b0edec3d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5b893f5d-9a07-496a-9ebb-0148b0edec3d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
df = pd.read_excel(io.BytesIO(files['Airline_V11_Test.xlsx']))

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Passanger_Name       0
# Route              140
# Source             101
# Destination        101
# Flying_month      2630
# Traveller_type     766
# Class                1
# Rating               5
# Review_title         0
# Review_content       0
# Verified          1520
# dtype: int64

# %%
Source = df[~df['Source'].isnull()]
Source[Source['Destination'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Passanger_Name, Route, Source, Destination, Flying_month, Traveller_type, Class, Rating, Review_title, Review_content, Verified]
# Index: []

# %%
def new_route(row):
  if (pd.isnull(row['Route']) == False):
    row['Route'] = str(row['Source']) + ' to ' + str(row['Destination'])
  return row
df = df.apply(new_route, axis =1)

# %%
df[['Source','Destination','Route']].sample(5)
# Out:
#                                                  Source  \
# 914      Bucharest - Henri Coandă International Airport
# 45                                    London - Heathrow
# 2762                                Singapore - Seletar
# 266                                   London - Heathrow
# 1188  Houston, TX - George Bush Intercontinental Air...
#
#                                          Destination  \
# 914                                London - Heathrow
# 45                                         Barcelona
# 2762                               London - Heathrow
# 266   Geneva - Geneva-Cointrin International Airport
# 1188                    Monrovia - Metropolitan Area
#
#                                                   Route
# 914   Bucharest - Henri Coandă International Airport...
# 45                       London - Heathrow to Barcelona
# 2762           Singapore - Seletar to London - Heathrow
# 266   London - Heathrow to Geneva - Geneva-Cointrin ...
# ...

# %%
df.isnull().sum()
# Out:
# Class                1
# Destination        101
# Flying_month      2630
# Passanger_Name       0
# Rating               5
# Review_content       0
# Review_title         0
# Route              140
# Source             101
# Traveller_type     766
# Unnamed: 0           0
# Verified          1520
# new_route          140
# dtype: int64

# %%
df[df['Source'] == 'Stanstead ( London )']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Passanger_Name, Route, Source, Destination, Flying_month, Traveller_type, Class, Rating, Review_title, Review_content, Verified]
# Index: []

# %%
def stanstead_to_heathrow(row):
  if row['Source'] == 'Stansted (London)':
    row['Source'] = 'London - Heathrow'
  return row
df = df.apply(stanstead_to_heathrow,axis = 1)

# %%
df['Source'].value_counts()
# Out:
# Source
# London - Heathrow                                1344
# London - Gatwick United                           288
# Los Angeles (CA) - International                   45
# Johannesburg - OR Tambo International Airport      41
# Vancouver - Vancouver International                39
#                                                  ...
# Fayetteville/Ft. Bragg (NC)                         1
# Corfu                                               1
# Sao Paulo - Viracopos                               1
# Bergen                                              1
# Arrecife/Lanzarote                                  1
# Name: count, Length: 274, dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Passanger_Name', 'Route', 'Source', 'Destination',
#        'Flying_month', 'Traveller_type', 'Class', 'Rating', 'Review_title',
#        'Review_content', 'Verified'],
#       dtype='object')

# %%
columns = ['Passanger_Name', 'Route', 'Source', 'Destination',
       'Flying_month', 'Traveller_type', 'Class', 'Rating', 'Review_title',
       'Review_content', 'Verified']
df.to_excel('Airline_V12_Test.xlsx', columns = ['Passanger_Name', 'Route', 'Source', 'Destination',
       'Flying_month', 'Traveller_type', 'Class', 'Rating', 'Review_title',
       'Review_content', 'Verified'])

# %%
df_LHR = df[df['Source'] == 'London - Heathrow']

# %%
df['Source'].value_counts()
# Out:
# Source
# London - Heathrow                                1344
# London - Gatwick United                           288
# Los Angeles (CA) - International                   45
# Johannesburg - OR Tambo International Airport      41
# Vancouver - Vancouver International                39
#                                                  ...
# Fayetteville/Ft. Bragg (NC)                         1
# Corfu                                               1
# Sao Paulo - Viracopos                               1
# Bergen                                              1
# Arrecife/Lanzarote                                  1
# Name: count, Length: 274, dtype: int64

# %%
df_LHR['Destination'].value_counts()
# Out:
# Destination
# Johannesburg - OR Tambo International Airport      41
# New York - John F. Kennedy (NY)                    34
# Bangkok, Suvarnabhumi International                32
# Dubai - Dubai International Airport United Arab    32
# Los Angeles (CA) - International                   29
#                                                    ..
# New Orleans, La                                     1
# Preveza/Lefkas                                      1
# Lahore                                              1
# Dubrovnik Croatia                                   1
# Hongkong                                            1
# Name: count, Length: 227, dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Passanger_Name       0
# Route              140
# Source             101
# Destination        101
# Flying_month      2630
# Traveller_type     766
# Class                1
# Rating               5
# Review_title         0
# Review_content       0
# Verified          1520
# dtype: int64

# %%
def new_route(row):
  if (pd.isnull(row['Route']) == False):
    row['Route'] = str(row['Source']) + ' to ' + str(row['Destination'])
  return row
df = df.apply(new_route, axis =1)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Passanger_Name       0
# Route              140
# Source             101
# Destination        101
# Flying_month      2630
# Traveller_type     766
# Class                1
# Rating               5
# Review_title         0
# Review_content       0
# Verified          1520
# dtype: int64

# %%
df1 = df[df['Route'].isnull()]
df2 = df1[df1['Source'].isnull() == False]
df3 = df2[~df2['Destination'].isnull()]
df3.index
# Out:
# Index([2917, 2933, 2939, 2993, 3003, 3013, 3033, 3042, 3052, 3054, 3060, 3079,
#        3092, 3114, 3118, 3120, 3121, 3169, 3178, 3179, 3205, 3207, 3218, 3228,
#        3332, 3336, 3342, 3350, 3360, 3374, 3395, 3439, 3449, 3454, 3455, 3460,
#        3463, 3471, 3535, 3565, 3576],
#       dtype='int64')

# %%
df.iloc[2917,2] = df.iloc[2917,3] + ' to ' + df.iloc[2917,4]
df.iloc[2917,2]
# Out:
# 'London - Heathrow to Saint Lucia'

# %%
for i in df3.index:
    df.iloc[i,2] = df.iloc[i,3] + ' to ' + df.iloc[i,4]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Passanger_Name       0
# Route               99
# Source             101
# Destination        101
# Flying_month      2630
# Traveller_type     766
# Class                1
# Rating               5
# Review_title         0
# Review_content       0
# Verified          1520
# dtype: int64

# %%
df['Route'].value_counts()
# Out:
# Route
# London - Heathrow to Johannesburg - OR Tambo International Airport                               41
# London - Heathrow to New York - John F. Kennedy (NY)                                             34
# London - Heathrow to Dubai - Dubai International Airport United Arab                             32
# London - Heathrow to Bangkok, Suvarnabhumi International                                         32
# Bangkok, Suvarnabhumi International to London - Heathrow                                         31
#                                                                                                  ..
# New Orleans, La to Monrovia - Metropolitan Area                                                   1
# Berlin, Tempelhof (ceased operating in 2008) to Hong Kong - International Airport (HKIA) Hong     1
# London - Heathrow to Casablanca, Mohamed V                                                        1
# ...

# %%
df['Route'].isnull().sum()
# Out:
# 99

# %%
df1 = df[~df['Route'].isnull()]
df2 = df1[df1['Source'].isnull()]
df3 = df2[df2['Destination'].isnull()]
df3
# Out:
#       Unnamed: 0 Passanger_Name       Route Source Destination Flying_month  \
# 2899        2899          D Lee  nan to nan    NaN         NaN          NaN
# 2902        2902     R Tompkins  nan to nan    NaN         NaN          NaN
#
#       Traveller_type           Class  Rating                     Review_title  \
# 2899  Family Leisure   Economy Class     8.0  British Airways customer review
# 2902  Family Leisure  Business Class     8.0  British Airways customer review
#
#                                          Review_content Verified
# 2899  This is more of a general review having travel...      NaN
# 2902  Family of 3 - 747 out (upper deck) 777 back. F...      NaN

# %%
import numpy as np
for i in [2899,2902]:
  df.iloc[i,2] = np.nan

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Passanger_Name', 'Route', 'Source', 'Destination',
#        'Flying_month', 'Traveller_type', 'Class', 'Rating', 'Review_title',
#        'Review_content', 'Verified'],
#       dtype='object')

# %%
df.to_excel('Airline_V13.xlsx', columns = ['Passanger_Name', 'Route', 'Source', 'Destination',
       'Flying_month', 'Traveller_type', 'Class', 'Rating', 'Review_title',
       'Review_content', 'Verified'])

# %%
from google.colab import files
files = files.upload()
# Out:
#      <input type="file" id="files-8dbad57b-dc94-4e55-b43e-3f877709f817" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8dbad57b-dc94-4e55-b43e-3f877709f817">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
import pandas as pd
df = pd.read_excel(io.BytesIO(files['Airline_V13.xlsx']))

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Passanger_Name       0
# Route              101
# Source             101
# Destination        101
# Flying_month      2630
# Traveller_type     766
# Class                1
# Rating               5
# Review_title         0
# Review_content       0
# Verified          1520
# dtype: int64

# %%
#df['Verified'].value_counts()

# %%
#df['Verified'].fillna('Not Verified', inplace = True)
#df['Verified'].value_counts()

# %%
columns = ['Passanger_Name','Review_content']
duplicates = df[df.duplicated(subset = columns ,keep='last')][columns]
duplicates
# Out:
#         Passanger_Name                                     Review_content
# 1204           C Cutts  BA026 7th July Seat 66B. Arrived HK off a conn...
# 2412    Richard Hodges  British Airways from Tampa to Gatwick on Boein...
# 2413    Richard Hodges  London Heathrow to Miami on one of British Air...
# 2838   Michael Stanley  BA 10 Bangkok to London Heathrow May 26th 2015...
# 2858      Kathleen Lee  Our flight on economy long distance from the A...
# ...                ...                                                ...
# 3499      Charlie Harm  Flew in Club World for the first time on the n...
# 3501      Derek Salter  LGW to AMS. Easy check-in at Gatwick with the ...
# 3504       Mark Murphy  I really do not have the energy to write very ...
# 3509      Peter Bedson  MCT-LHR-MAN and LHR-MCT I think you need to fl...
# 3517  Robert Sakakeeny  BA 214 in the late spring os a 747-400. Lie-fl...
#
# [74 rows x 2 columns]

# %%
df.drop_duplicates(subset=columns, keep = 'last', inplace = True)

# %%
len(df)
# Out:
# 3506

# %%
df['Route'].value_counts()
# Out:
# Route
# London - Heathrow to Johannesburg - OR Tambo International Airport      39
# London - Heathrow to New York - John F. Kennedy (NY)                    33
# London - Heathrow to Dubai - Dubai International Airport United Arab    32
# London - Heathrow to Bangkok, Suvarnabhumi International                32
# Bangkok, Suvarnabhumi International to London - Heathrow                30
#                                                                         ..
# London - Heathrow to Preveza/Lefkas                                      1
# Ottawa - Hull to Ahmedabad                                               1
# Antigua, V.C. Bird International Antigua and to London - Heathrow        1
# London - Heathrow to Rio de Janeiro                                      1
# London - Heathrow to Hongkong                                            1
# Name: count, Length: 876, dtype: int64

# %%
import matplotlib.pyplot as plt
traveller_type_by_class = df.groupby(['Class', 'Traveller_type']).size().unstack().fillna(0)

traveller_type_by_class.plot(kind='bar', stacked=True, figsize=(12, 6), colormap='viridis')
plt.title('Composition of Traveller Types within Each Class')
plt.xlabel('Class')
plt.ylabel('Count of Travellers')

plt.tight_layout()
plt.show()

# %%
business_class = df[df['Class'] == 'Business Class']
business_class['Traveller_type'].value_counts()
# Out:
# Traveller_type
# Couple Leisure    333
# Business          277
# Solo Leisure      173
# Family Leisure     82
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8, 4))
sns.histplot(df['Rating'], kde=True, bins=10)
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 4))
class_counts = df['Class'].value_counts()
plt.figure(figsize=(8, 4))
sns.barplot(x=class_counts.index, y=class_counts.values, palette="husl")
plt.title('Distribution of Travel Class')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-13-fed4c1c4bb25>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=class_counts.index, y=class_counts.values, palette="husl")

# %%
plt.figure(figsize=(5, 4))
# Distribution of 'Traveller_type'
traveller_type_counts = df['Traveller_type'].value_counts()
ax = sns.barplot(x=traveller_type_counts.index,
            y=traveller_type_counts.values, palette='Set2')
plt.title('Distribution of Traveller Types')
plt.xlabel('Traveller Type')
plt.ylabel('Frequency')

for p in ax.patches:
    ax.annotate(format(int(p.get_height()), ','),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom',
                color='black', fontsize=6,fontweight='bold',
                xytext=(0, 5),
                textcoords='offset points')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-14-e538c32c197a>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=traveller_type_counts.index,

# %%
top_routes = df['Route'].value_counts().head(10)
plt.figure(figsize=(6,4))
sns.barplot(x=top_routes.values, y=top_routes.index, palette="viridis")
plt.title('Top 10 Most Popular Routes',color ='navy')
plt.xlabel('Number of Flights', color='navy')
plt.ylabel('Routes',color='navy')

# %%
import matplotlib.pyplot as plt
class_counts = df['Class'].value_counts()
traveller_type_counts = df['Traveller_type'].value_counts()
fig, axes = plt.subplots(1, 2, figsize=(12,6))
axes[0].pie(class_counts, labels=class_counts.index, autopct='%1.1f%%', startangle=90, textprops={'color':"black"})
axes[0].set_title('Distribution of Travel Class', color = 'navy')
axes[1].pie(traveller_type_counts, labels=traveller_type_counts.index, autopct='%1.1f%%', startangle=90, textprops={'color':"black"})
axes[1].set_title('Distribution of Traveller Types', color = 'navy')
plt.tight_layout()
plt.show()

# %%
top_routes = df['Route'].value_counts().head(10)
plt.figure(figsize=(6,4))
sns.barplot(x=top_routes.values, y=top_routes.index, palette="viridis")
plt.title('Top 10 Most Popular Routes',color ='navy')
plt.xlabel('Number of Flights', color='navy')
plt.ylabel('Routes',color='navy')
top_sources = df['Source'].value_counts().head(10)
plt.figure(figsize=(8, 4))
sns.barplot(x=top_sources.values, y=top_sources.index, palette="muted")
#plt.title('Top 10 Most Common Source Airports')
plt.xlabel('Number of Departures', color='navy')
plt.ylabel('Source Airports', color='navy')
top_destinations = df['Destination'].value_counts().head(10)
plt.figure(figsize=(8, 4))
sns.barplot(x=top_destinations.values, y=top_destinations.index, palette="muted")
#plt.title('Top 10 Most Common Destination Airports')
plt.xlabel('Number of Arrivals',color='navy')
plt.ylabel('Destination Airports',color='navy')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure column names and data integrity
average_rating_by_class = df.groupby('Class')['Rating'].mean().dropna().sort_values()
average_rating_by_traveller_type = df.groupby('Traveller_type')['Rating'].mean().dropna().sort_values()

# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(14, 7))

# Subplot 1: Average Rating by Class
sns.barplot(x=average_rating_by_class.index, y=average_rating_by_class.values, palette='Set2', ax=axes[0])
axes[0].set_title('Average Rating by Class')
axes[0].set_xlabel('Class')
axes[0].set_ylabel('Average Rating')
axes[0].set_ylim(0, 10)  # Assuming rating scale is 1-10

# Subplot 2: Average Rating by Traveller Type
sns.barplot(x=average_rating_by_traveller_type.index, y=average_rating_by_traveller_type.values, palette='Set2', ax=axes[1])
axes[1].set_title('Average Rating by Traveller Type')
axes[1].set_xlabel('Traveller Type')
axes[1].set_ylabel('Average Rating')
axes[1].set_ylim(0, 10)  # Assuming rating scale is 1-10
axes[1].tick_params(axis='x', rotation=45)  # Rotate x labels for better readability

# Adjust layout
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure data columns are correct and clean
average_rating_by_class = df.groupby('Class')['Rating'].mean().dropna().sort_values()
average_rating_by_traveller_type = df.groupby('Traveller_type')['Rating'].mean().dropna().sort_values()

# Create figure with two subplots (vertically stacked)
fig, axes = plt.subplots(1,2, figsize=(8,6), sharey=True)

# Subplot 1: Average Rating by Class
sns.barplot(x=average_rating_by_class.index, y=average_rating_by_class.values, palette='Set2', ax=axes[0])
axes[0].set_title('Average Rating by Class', color='navy')
axes[0].set_xlabel('Class',color='navy')
axes[0].set_ylabel('Average Rating', color='navy')
axes[0].set_ylim(0, 10)
axes[0].tick_params(axis='x', rotation=45)

# Subplot 2: Average Rating by Traveller Type
sns.barplot(x=average_rating_by_traveller_type.index, y=average_rating_by_traveller_type.values, palette='Set2', ax=axes[1])
axes[1].set_title('Average Rating by Traveller Type',color='navy')
axes[1].set_xlabel('Traveller Type', color='navy')
axes[1].set_ylabel('Average Rating', color='navy')
axes[1].set_ylim(0, 10)
axes[1].tick_params(axis='x', rotation=45)

# Adjust layout for a clean look
plt.tight_layout()
plt.show()

# %%
from nltk.sentiment import vader
import nltk
import requests
from collections import Counter
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
reviews = df['Review_content']
words = []
for review in reviews:
    words.extend(review.split())
stopwords = nltk.corpus.stopwords.words('english')
key_words = [word for word in words if word not in stopwords and word not in
             ['I', 'The','would','one','get','-']]

word_counts = Counter(key_words)
top_20_words = word_counts.most_common(20)
filtered_words = [
    (word, count) for word, count in top_20_words
    if word not in stopwords and word not in ['I', 'The','would','one','get','-']
    ]
labels, values = zip(*top_20_words)
plt.bar(labels, values)
plt.xticks(rotation=90)
plt.show()

# %%
reviews = df['Review_content']
words = []
for review in reviews:
    words.extend(review.split())
stopwords = nltk.corpus.stopwords.words('english')
key_words = [word for word in words if word not in stopwords and word not in
             ['I', 'The','would','one','get','-']]

word_counts = Counter(key_words)
top_20_words = word_counts.most_common(20)
filtered_words = [
    (word, count) for word, count in top_20_words
    if word not in stopwords and word not in ['I', 'The','would','one','get','-']
    ]
labels, values = zip(*top_20_words)

plt.figure(figsize=(6,4))
sns.barplot(x=values, y=labels, palette="viridis")
plt.xlabel('Frequency', color='navy')
plt.ylabel('Keywords',color='navy')
# Out:
# <ipython-input-51-63d5e692b348>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=values, y=labels, palette="viridis")
# Text(0, 0.5, 'Keywords')

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(random_state=42).generate(' '.join(df['Review_content']))
plt.imshow(wordcloud, interpolation= 'bilinear')
plt.axis("off")
plt.show()

# %%
import io
import pandas as pd
from google.colab import files

# %%
files = files.upload()
# Out:
#      <input type="file" id="files-b51674c6-d9be-4bac-9ec8-77b18cd01e86" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b51674c6-d9be-4bac-9ec8-77b18cd01e86">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel(io.BytesIO(files['Airline_V13.xlsx']))

# %%
data = df

# Assuming data is your DataFrame
data['Flying_month'] = data['Flying_month'].astype(str)

# Split the 'Flying_month' column into 'Month' and 'Year'
data[['Month', 'Year']] = data['Flying_month'].str.split('-', expand=True)

# Display the first few rows to verify
print(data[['Flying_month', 'Month', 'Year']].head())
# Out:
#   Flying_month Month  Year
# 0       Jun-23   Jun    23
# 1       Mar-23   Mar    23
# 2          nan   nan  None
# 3       Jun-23   Jun    23
# 4          nan   nan  None

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Passanger_Name', 'Route', 'Source', 'Destination',
#        'Flying_month', 'Traveller_type', 'Class', 'Rating', 'Review_title',
#        'Review_content', 'Verified', 'Month', 'Year'],
#       dtype='object')

# %%
data.drop(columns = ['Unnamed: 0'])
# Out:
#          Passanger_Name                                              Route  \
# 0            Paige Boet               New Orleans, La to London - Heathrow
# 1               S Layne  London - Heathrow to Amman - Queen Alia Intern...
# 2           E Lanewoski        London - Heathrow to Bodrum - Milas Airport
# 3           Joel Burman  Amman - Queen Alia International Airport Jorda...
# 4               R Vines  Belfast - George Best Belfast City Airport Uni...
# ...                 ...                                                ...
# 3575           W Benson  London - Heathrow to Hong Kong - International...
# 3576           S Luqman  Bridgetown - Grantley Adams International to L...
# 3577            D Smith  London - Heathrow to New York - John F. Kenned...
# 3578           W Benson  Hong Kong - International Airport (HKIA) Hong ...
# 3579  Michael Dielissen  Toronto - Toronto Pearson International Airpor...
#
#                                                  Source  \
# ...

# %%
data.to_excel('Airline_V14_Test.xlsx')

# %%
data.isnull().sum()
# Out:
# Unnamed: 0           0
# Passanger_Name       0
# Route              101
# Source             101
# Destination        101
# Flying_month         0
# Traveller_type     766
# Class                1
# Rating               5
# Review_title         0
# Review_content       0
# Verified          1520
# Month                0
# Year              2630
# dtype: int64

# %%
data['Month'].sample(20)
# Out:
# 240     Jun
# 3179    nan
# 176     nan
# 1066    nan
# 2717    nan
# 3438    nan
# 939     nan
# 1477    nan
# 1875    Oct
# 915     Dec
# 874     nan
# 103     nan
# 993     nan
# 2999    nan
# 852     nan
# 2306    nan
# 2528    nan
# 896     nan
# 2943    nan
# 1687    nan
# Name: Month, dtype: object

# %%
import numpy as np
def nan_into_blank(row):
  if row['Flying_month'] == 'nan':
    row['Flying_month'] = np.nan
    row['Month'] = np.nan
  return row
data = data.apply(nan_into_blank, axis = 1)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0           0
# Passanger_Name       0
# Route              101
# Source             101
# Destination        101
# Flying_month      2630
# Traveller_type     766
# Class                1
# Rating               5
# Review_title         0
# Review_content       0
# Verified          1520
# Month             2630
# Year              2630
# dtype: int64

# %%
data.to_excel('Airline_V15_Test.xlsx')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(14, 7))
sns.lineplot(data=df, x='Flying_month', y='Rating', marker='o')
plt.title('Ratings Over Flying Months')
plt.xlabel('Flying Month')
plt.ylabel('Rating')
plt.show()

# %%
# Popular Flying Months
plt.figure(figsize=(14, 7))
sns.countplot(data=df, x='Flying_month', order=df['Flying_month'].value_counts().index[1:10])
plt.title('Top 10 Most Popular Flying Months')
plt.xlabel('Flying Month')
plt.ylabel('Number of Bookings')
plt.xticks(rotation=45)
plt.show()

# %%
# Exclude rows where 'Month' is NaN
df_nonan = data.dropna(subset=['Month'])

# Ensure the 'Month' column follows the desired order
df_nonan['Month'] = pd.Categorical(df_nonan['Month'], categories=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], ordered=True)

# Plotting Ratings over Months excluding NaN values
plt.figure(figsize=(14, 7))
sns.lineplot(data=df_nonan, x='Month', y='Rating', marker='o')
plt.title('Ratings Over Months')
plt.xlabel('Month')
plt.ylabel('Rating')
plt.show()
# Out:
# <ipython-input-67-6c8780f8c82b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nonan['Month'] = pd.Categorical(df_nonan['Month'], categories=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], ordered=True)
